# %% [markdown]
# # Assemble Data

# %%
import pandas as pd

ClinVar_2019_47a = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019_dbnsfp47a.hg19_multianno.csv")
sum(ClinVar_2019_47a['MutPred_score']=='.')

# %%
import pandas as pd

ClinVar_2019 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019Set.csv")
ClinVar_2019_47a = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019_dbnsfp47a.hg19_multianno.csv")
ClinVar_2019_29 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019_dbnsfp29.hg19_multianno.csv")
ClinVar_2019_27 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019_dbnsfp27.hg19_multianno.csv")

ClinVar_2019_meta = ClinVar_2019[['hg19_chr', 'hg19_pos(1-based)', 'ref', 'alt', 'rs_dbSNP151',
                                  'genename', 'Ensembl_geneid', 'Ensembl_transcriptid',
                                  'Ensembl_proteinid', 'Uniprot_acc', 'Uniprot_entry', 'aavar', 'clnsig',
                                  'MAF', 'REVEL_score', 'BayesDel_nsfp33a_noAF']].copy()

ClinVar_2019_meta[['SIFT_score',
       'Polyphen2_HDIV_score', 'Polyphen2_HVAR_score', 'LRT_score',
       'MutationTaster_score', 'MutationAssessor_score', 'FATHMM_score',
       'VEST3_score', 'GERP++_RS', 'phyloP46way_primate',
       'phyloP46way_placental', 'phyloP100way_vertebrate',
       'phastCons46way_primate', 'phastCons46way_placental',
       'phastCons100way_vertebrate', 'SiPhy_29way_logOdds',]] = ClinVar_2019_27[['SIFT_score',
       'Polyphen2_HDIV_score', 'Polyphen2_HVAR_score', 'LRT_score',
       'MutationTaster_score', 'MutationAssessor_score', 'FATHMM_score',
       'VEST3_score', 'GERP++_RS', 'phyloP46way_primate',
       'phyloP46way_placental', 'phyloP100way_vertebrate',
       'phastCons46way_primate', 'phastCons46way_placental',
       'phastCons100way_vertebrate', 'SiPhy_29way_logOdds',]]

ClinVar_2019_meta['PROVEAN_score'] = ClinVar_2019_29['PROVEAN_score']
ClinVar_2019_meta['MutPred_score'] = ClinVar_2019_47a['MutPred_score']

columns_to_process = ClinVar_2019_meta.columns[
    ClinVar_2019_meta.apply(lambda col: col.astype(str).str.contains(";").any())
]

print(columns_to_process)

def process_cell(cell):
    if isinstance(cell, str) and ";" in cell:
        try:
            values = [float(x) for x in cell.split(";") if x != '.']
            if values: 
                return sum(values) / len(values)
        except:
            return cell
    return cell

ClinVar_2019_meta[columns_to_process] = ClinVar_2019_meta[columns_to_process].applymap(process_cell)

columns_to_process = ClinVar_2019_meta.columns[
    ClinVar_2019_meta.apply(lambda col: col.astype(str).str.contains(";").any())
]

print(columns_to_process)

display(ClinVar_2019_meta)

ClinVar_2019_meta.to_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019Set_meta.csv", index=False)

# %%
import pandas as pd

ClinVar_2020 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2020Set.csv")

ClinVar_2020_47a = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2020_dbnsfp47a.hg19_multianno.csv")

ClinVar_2020_29 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2020_dbnsfp29.hg19_multianno.csv")

ClinVar_2020_27 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2020_dbnsfp27.hg19_multianno.csv")

ClinVar_2020_meta = ClinVar_2020[['hg19_chr', 'hg19_pos(1-based)', 'ref', 'alt', 'rs_dbSNP151',
                                  'genename', 'Ensembl_geneid', 'Ensembl_transcriptid',
                                  'Ensembl_proteinid', 'Uniprot_acc', 'Uniprot_entry', 'aavar', 'clnsig',
                                  'MAF', 'REVEL_score', 'BayesDel_nsfp33a_noAF']].copy()

ClinVar_2020_meta[['SIFT_score',
       'Polyphen2_HDIV_score', 'Polyphen2_HVAR_score', 'LRT_score',
       'MutationTaster_score', 'MutationAssessor_score', 'FATHMM_score',
       'VEST3_score', 'GERP++_RS', 'phyloP46way_primate',
       'phyloP46way_placental', 'phyloP100way_vertebrate',
       'phastCons46way_primate', 'phastCons46way_placental',
       'phastCons100way_vertebrate', 'SiPhy_29way_logOdds',]] = ClinVar_2020_27[['SIFT_score',
       'Polyphen2_HDIV_score', 'Polyphen2_HVAR_score', 'LRT_score',
       'MutationTaster_score', 'MutationAssessor_score', 'FATHMM_score',
       'VEST3_score', 'GERP++_RS', 'phyloP46way_primate',
       'phyloP46way_placental', 'phyloP100way_vertebrate',
       'phastCons46way_primate', 'phastCons46way_placental',
       'phastCons100way_vertebrate', 'SiPhy_29way_logOdds',]]

ClinVar_2020_meta['PROVEAN_score'] = ClinVar_2020_29['PROVEAN_score']
ClinVar_2020_meta['MutPred_score'] = ClinVar_2020_47a['MutPred_score']

columns_to_process = ClinVar_2020_meta.columns[
    ClinVar_2020_meta.apply(lambda col: col.astype(str).str.contains(";").any())
]

print(columns_to_process)

ClinVar_2020_meta[columns_to_process] = ClinVar_2020_meta[columns_to_process].applymap(process_cell)

columns_to_process = ClinVar_2020_meta.columns[
    ClinVar_2020_meta.apply(lambda col: col.astype(str).str.contains(";").any())
]

print(columns_to_process)

display(ClinVar_2020_meta)
ClinVar_2020_meta.to_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2020Set_meta.csv", index=False)

# %%
import pandas as pd

GnomAD_set = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/GnomADSet.csv")

GnomAD_set_47a = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/GnomADSet_dbnsfp47a.hg19_multianno.csv")

GnomAD_set_29 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/GnomADSet_dbnsfp29.hg19_multianno.csv")

GnomAD_set_27 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/GnomADSet_dbnsfp27.hg19_multianno.csv")

GnomAD_set_meta = GnomAD_set[['hg19_chr', 'hg19_pos(1-based)', 'ref', 'alt', 'rs_dbSNP151',
                                  'genename', 'Ensembl_geneid', 'Ensembl_transcriptid',
                                  'Ensembl_proteinid', 'Uniprot_acc', 'Uniprot_entry', 'aavar',
                                  'MAF', 'REVEL_score', 'BayesDel_nsfp33a_noAF']].copy()

GnomAD_set_meta[['SIFT_score',
       'Polyphen2_HDIV_score', 'Polyphen2_HVAR_score', 'LRT_score',
       'MutationTaster_score', 'MutationAssessor_score', 'FATHMM_score',
       'VEST3_score', 'GERP++_RS', 'phyloP46way_primate',
       'phyloP46way_placental', 'phyloP100way_vertebrate',
       'phastCons46way_primate', 'phastCons46way_placental',
       'phastCons100way_vertebrate', 'SiPhy_29way_logOdds',]] = GnomAD_set_27[['SIFT_score',
       'Polyphen2_HDIV_score', 'Polyphen2_HVAR_score', 'LRT_score',
       'MutationTaster_score', 'MutationAssessor_score', 'FATHMM_score',
       'VEST3_score', 'GERP++_RS', 'phyloP46way_primate',
       'phyloP46way_placental', 'phyloP100way_vertebrate',
       'phastCons46way_primate', 'phastCons46way_placental',
       'phastCons100way_vertebrate', 'SiPhy_29way_logOdds',]]

GnomAD_set_meta['PROVEAN_score'] = GnomAD_set_29['PROVEAN_score']
GnomAD_set_meta['MutPred_score'] = GnomAD_set_47a['MutPred_score']


columns_to_process = GnomAD_set_meta.columns[
    GnomAD_set_meta.apply(lambda col: col.astype(str).str.contains(";").any())
]

print(columns_to_process)

GnomAD_set_meta[columns_to_process] = GnomAD_set_meta[columns_to_process].applymap(process_cell)

columns_to_process = GnomAD_set_meta.columns[
    GnomAD_set_meta.apply(lambda col: col.astype(str).str.contains(";").any())
]

print(columns_to_process)

display(GnomAD_set_meta)
GnomAD_set_meta.to_csv("/gpfs/home/pl2948/VariantInterpretation/Data/GnomADSet_meta.csv", index=False)

# %% [markdown]
# # Import MetaPred Dataset

# %%
select_column = ['REVEL_score', 
                 'BayesDel_nsfp33a_noAF', 
                 'SIFT_score',
                 'Polyphen2_HDIV_score', 
                 'Polyphen2_HVAR_score', 
                 'LRT_score',
                 'MutationTaster_score', 
                 'MutationAssessor_score', 
                 'FATHMM_score',
                 'VEST3_score', 
                 'GERP++_RS', 
                 'phyloP46way_primate',
                 'phyloP46way_placental', 
                 'phyloP100way_vertebrate',
                 'phastCons46way_primate', 'phastCons46way_placental',
                 'phastCons100way_vertebrate', 
                 'SiPhy_29way_logOdds', 
                 'PROVEAN_score',
                 'MutPred_score',
                 'ClinVar_annotation'
                ]

# %% [markdown]
# ## ClinVar 2019

# %%
import pandas as pd

ClinVar_2019 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2019Set_meta.csv")
ClinVar_2019

# %%
calibration_data = ClinVar_2019.rename(columns={'clnsig': 'ClinVar_annotation'})
del ClinVar_2019

ClinVar_ann = {
    'Benign/Likely_benign': 0, 
    'Likely_benign': 0, 
    'Pathogenic': 1,
    'Likely_pathogenic': 1, 
    'Benign': 0, 
    'Pathogenic/Likely_pathogenic': 1
    }

calibration_data['ClinVar_annotation'] = calibration_data['ClinVar_annotation'].map(ClinVar_ann)
calibration_data = calibration_data[calibration_data['ClinVar_annotation'].notna()]
calibration_data = calibration_data[select_column]

print(len(calibration_data))

for col in select_column[:-1]:
    calibration_data[col] = pd.to_numeric(calibration_data[col], errors='coerce')
    if col in ['SIFT_score', 'FATHMM_score', 'LRT_score', 'PROVEAN_score']:
        calibration_data[col] *=-1

calibration_data = calibration_data.reset_index(drop=True)

display(calibration_data)
print(calibration_data.isna().sum())

# %%
print("Pathogenic", sum(calibration_data['ClinVar_annotation']==1))
print("Benign", sum(calibration_data['ClinVar_annotation']==0))

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

def calculate_roc_and_auc(y_true, y_score, label):
    y_true = np.array(y_true)
    y_score = np.array(y_score)

    valid_indices = ~np.isnan(y_score) & ~np.isnan(y_true)
    y_true_cleaned = y_true[valid_indices]
    y_score_cleaned = y_score[valid_indices]

    fpr, tpr, _ = roc_curve(y_true_cleaned, y_score_cleaned)
    roc_auc = auc(fpr, tpr)
    return fpr, tpr, roc_auc, label

roc_curves = []

for col in select_column[:-1]:  # Exclude 'ClinVar_annotation'
    roc_curves.append(calculate_roc_and_auc(
        calibration_data['ClinVar_annotation'], calibration_data[col], col))

# Plot ROC curves
plt.figure(figsize=(8, 6))
for fpr, tpr, roc_auc, label in roc_curves:
    plt.plot(fpr, tpr, label=f'{label} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Reference diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(loc='lower right')
# plt.grid()
plt.show()

# %% [markdown]
# ## ClinVar 2020

# %%
import pandas as pd

ClinVar_2020 = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/ClinVar2020Set_meta.csv")
ClinVar_2020

# %%
test_data = ClinVar_2020.rename(columns={'clnsig': 'ClinVar_annotation'})
del ClinVar_2020

ClinVar_ann = {
    'Benign/Likely_benign': 0, 
    'Likely_benign': 0, 
    'Pathogenic': 1,
    'Likely_pathogenic': 1, 
    'Benign': 0, 
    'Pathogenic/Likely_pathogenic': 1
    }

test_data['ClinVar_annotation'] = test_data['ClinVar_annotation'].map(ClinVar_ann)
test_data = test_data[test_data['ClinVar_annotation'].notna()]
test_data = test_data[select_column]

print(len(test_data))

for col in select_column[:-1]:
    test_data[col] = pd.to_numeric(test_data[col], errors='coerce')
    # test_data = test_data[(test_data[col]!='.') & (test_data[col].notna())]
    # print(col, len(test_data))
    if col in ['SIFT_score', 'FATHMM_score', 'LRT_score', 'PROVEAN_score']:
        test_data[col] *=-1

test_data = test_data.reset_index(drop=True)

display(test_data)
print(test_data.isna().sum())

# %%
print("Pathogenic", sum(test_data['ClinVar_annotation']==1))
print("Benign", sum(test_data['ClinVar_annotation']==0))

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

roc_curves = []

for col in select_column[:-1]:  # Exclude 'ClinVar_annotation'
    roc_curves.append(calculate_roc_and_auc(
        test_data['ClinVar_annotation'], test_data[col], col))

plt.figure(figsize=(8, 6))
for fpr, tpr, roc_auc, label in roc_curves:
    plt.plot(fpr, tpr, label=f'{label} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Reference diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(loc='lower right')
# plt.grid()
plt.show()

# %% [markdown]
# ## gnomAD set

# %%
import pandas as pd
gnomAD_set = pd.read_csv("/gpfs/home/pl2948/VariantInterpretation/Data/GnomADSet_meta.csv")
gnomAD_set

# %%
gnomAD_set = gnomAD_set[select_column[:-1]]

# print(len(gnomAD_set))

for col in select_column[:-1]:
    gnomAD_set[col] = pd.to_numeric(gnomAD_set[col], errors='coerce')
    # gnomAD_set = gnomAD_set[(gnomAD_set[col]!='.') & (gnomAD_set[col].notna())]
    # print(col, len(gnomAD_set))
    if col in ['SIFT_score', 'FATHMM_score', 'LRT_score', 'PROVEAN_score']:
        gnomAD_set[col] *=-1

gnomAD_set = gnomAD_set.reset_index(drop=True)
    
display(gnomAD_set)
print(gnomAD_set.isna().sum())

# %% [markdown]
# # Single Tool 1D calibration

# %%
import copy
import numpy as np

select_column = ['REVEL_score', 
                 'BayesDel_nsfp33a_noAF', 
                 'SIFT_score',
                 'Polyphen2_HDIV_score', 
                 'Polyphen2_HVAR_score', 
                 'LRT_score',
                 'MutationTaster_score', 
                 'MutationAssessor_score', 
                 'FATHMM_score',
                 'VEST3_score', 
                 'GERP++_RS', 
                 'phyloP46way_primate',
                 'phyloP46way_placental', 
                 'phyloP100way_vertebrate',
                 'phastCons46way_primate', 'phastCons46way_placental',
                 'phastCons100way_vertebrate', 
                 'SiPhy_29way_logOdds', 
                 'PROVEAN_score',
                 'MutPred_score',
                 'ClinVar_annotation'
                ]

calibration_feature = calibration_data[select_column[:-1]].to_numpy()
test_feature = test_data[select_column[:-1]].to_numpy()
regularization_feature = gnomAD_set[select_column[:-1]].to_numpy()

calibration_label = calibration_data[select_column[-1]].to_numpy()
calibration_label_bk = copy.deepcopy(calibration_label)
test_label = test_data[select_column[-1]].to_numpy()
test_label_bk = copy.deepcopy(test_label)

print(calibration_feature.shape, test_feature.shape, regularization_feature.shape)

# %%
import torch
import gc
from P_KNN_GPU import get_bootstrap_KNN_score_gpu, get_P_KNN_ACMG_score, evaluate_result_1D
import copy

#Parameter setting
Pprior = 0.0441; # Prior probability of pathogenicity (changes w/ c)
w_calibration=None
n_calibration_in_window = 100;   # minimum number of clinvar variants in a local window
frac_regularization_in_window=0.03
batch_size = 512 # This is for A100, if V100, use 512
normalization= None
impute = False
mi_scaling = False
n_bootstrap = 100

p_value = 0.05
logbase = 1124

combine_data = pd.DataFrame()

for i in range(len(select_column)-1):   
    condition_string = f"{select_column[i]}_meta"
    select_feature = i

    valid_calibration_idx = ~np.isnan(calibration_feature[:,select_feature]) 
    calibration_array = calibration_feature[valid_calibration_idx][:,select_feature].reshape(-1, 1)
    calibration_label = copy.deepcopy(calibration_label_bk[valid_calibration_idx])

    valid_test_idx = ~np.isnan(test_feature[:,select_feature])
    test_array = test_feature[valid_test_idx][:,select_feature].reshape(-1, 1)
    test_label = copy.deepcopy(test_label_bk[valid_test_idx])

    valid_regularization_idx = ~np.isnan(regularization_feature[:,select_feature])
    regularization_array = regularization_feature[valid_regularization_idx][:,select_feature].reshape(-1, 1)

    print("")
    print(f"Tool {condition_string}")
    print(f"calibration size: {calibration_array.shape[0]}, test size: {test_array.shape[0]}")

    torch.cuda.empty_cache()
    gc.collect()

    test_results_array = get_bootstrap_KNN_score_gpu(calibration_array, test_array, regularization_array, 
                                                     calibration_label, Pprior, w_calibration, 
                                                     n_calibration_in_window, frac_regularization_in_window, 
                                                     normalization, impute, mi_scaling, n_bootstrap, batch_size)

    np.save(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy', test_results_array)

    test_results_array = np.load(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy')

    P_KNN_pathogenic, P_KNN_benign, ACMG_scores = get_P_KNN_ACMG_score(test_results_array, p_value, Pprior, logbase)

    evidence_strength_data, pathogenic_calibration_dict, benign_calibration_dict = evaluate_result_1D(test_results_array,
                                                                                                      test_array,
                                                                                                      test_label, 
                                                                                                      p_value, 
                                                                                                      Pprior, 
                                                                                                      logbase, 
                                                                                                      category = condition_string, 
                                                                                                      show_plot=True, 
                                                                                                      save_name=condition_string)

    combine_data = pd.concat([combine_data, evidence_strength_data], ignore_index=True)

    print("pathogenic evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Pathogenic variants']['Score'].mean():.3f}")
    print("benign evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Benign variants']['Score'].mean():.3f}")

# %% [markdown]
# # Integrating All Elemenrary tools (REVEL)

# %% [markdown]
# ## REVEL component

# %%
import copy
import numpy as np

select_column = ['REVEL_score', 
                 'BayesDel_nsfp33a_noAF', 
                 'SIFT_score',
                 'Polyphen2_HDIV_score', 
                 'Polyphen2_HVAR_score', 
                 'LRT_score',
                 'MutationTaster_score', 
                 'MutationAssessor_score', 
                 'FATHMM_score',
                 'VEST3_score', 
                 'GERP++_RS', 
                 'phyloP46way_primate',
                 'phyloP46way_placental', 
                 'phyloP100way_vertebrate',
                 'phastCons46way_primate', 'phastCons46way_placental',
                 'phastCons100way_vertebrate', 
                 'SiPhy_29way_logOdds', 
                 'PROVEAN_score',
                 'MutPred_score',
                 'ClinVar_annotation'
                ]

calibration_feature = calibration_data[select_column[2:-1]].to_numpy()
test_feature = test_data[select_column[2:-1]].to_numpy()
regularization_feature = gnomAD_set[select_column[2:-1]].to_numpy()

calibration_label = calibration_data[select_column[-1]].to_numpy()
calibration_label_bk = copy.deepcopy(calibration_label)
test_label = test_data[select_column[-1]].to_numpy()
test_label_bk = copy.deepcopy(test_label)

print(calibration_feature.shape, test_feature.shape, regularization_feature.shape)

# %%
import torch
import gc
from P_KNN_GPU import get_bootstrap_KNN_score_gpu, get_P_KNN_ACMG_score, evaluate_result
import copy

#Parameter setting
Pprior = 0.0441; # Prior probability of pathogenicity (changes w/ c)
w_calibration = None
n_calibration_in_window = 100   # minimum number of clinvar variants in a local window
frac_regularization_in_window = 0.03
batch_size = 512 # This is for A100, if V100, use 512
normalization= 'rank'
impute = True
mi_scaling = True
n_bootstrap = 100

p_value = 0.05
logbase = 1124

condition_string = 'P-KNN_REVELComponent_meta'
valid_calibration_idx = ~np.isnan(calibration_feature).all(axis=1) 
calibration_array = calibration_feature[valid_calibration_idx]
calibration_label = copy.deepcopy(calibration_label_bk[valid_calibration_idx])

valid_test_idx = ~np.isnan(test_feature).all(axis=1) 
test_array = test_feature[valid_test_idx]
test_label = copy.deepcopy(test_label_bk[valid_test_idx])

valid_regularization_idx = ~np.isnan(regularization_feature).all(axis=1) 
regularization_array = regularization_feature[valid_regularization_idx]

print(f"calibration size: {calibration_array.shape[0]}, test size: {test_array.shape[0]}")

torch.cuda.empty_cache()
gc.collect()

test_results_array = get_bootstrap_KNN_score_gpu(calibration_array, test_array, regularization_array, 
                                                 calibration_label, Pprior, w_calibration, 
                                                 n_calibration_in_window, frac_regularization_in_window, 
                                                 normalization, impute, mi_scaling, n_bootstrap, batch_size)

np.save(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy', test_results_array)

test_results_array = np.load(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy')

P_KNN_pathogenic, P_KNN_benign, ACMG_scores = get_P_KNN_ACMG_score(test_results_array, p_value, Pprior, logbase)

test_data.loc[valid_test_idx, f"ACMGLLR"] = ACMG_scores 

evidence_strength_data, pathogenic_calibration_dict, benign_calibration_dict = evaluate_result(test_results_array,
                                                                                                  test_label, 
                                                                                                  p_value, 
                                                                                                  Pprior, 
                                                                                                  logbase, 
                                                                                                  category = condition_string, 
                                                                                                  show_plot=True, 
                                                                                                  save_name="REVELComponent")

combine_data = pd.concat([combine_data, evidence_strength_data], ignore_index=True)
    
print("pathogenic evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Pathogenic variants']['Score'].mean():.3f}")
print("benign evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Benign variants']['Score'].mean():.3f}")

# %% [markdown]
# ## REVEL Plus component

# %%
import copy
import numpy as np

select_column = ['REVEL_score', 
                 'BayesDel_nsfp33a_noAF', 
                 'SIFT_score',
                 'Polyphen2_HDIV_score', 
                 'Polyphen2_HVAR_score', 
                 'LRT_score',
                 'MutationTaster_score', 
                 'MutationAssessor_score', 
                 'FATHMM_score',
                 'VEST3_score', 
                 'GERP++_RS', 
                 'phyloP46way_primate',
                 'phyloP46way_placental', 
                 'phyloP100way_vertebrate',
                 'phastCons46way_primate', 'phastCons46way_placental',
                 'phastCons100way_vertebrate', 
                 'SiPhy_29way_logOdds', 
                 'PROVEAN_score',
                 'MutPred_score',
                 'ClinVar_annotation'
                ]

calibration_feature = calibration_data[[select_column[0]]+select_column[2:-1]].to_numpy()
test_feature = test_data[[select_column[0]]+select_column[2:-1]].to_numpy()
regularization_feature = gnomAD_set[[select_column[0]]+select_column[2:-1]].to_numpy()

calibration_label = calibration_data[select_column[-1]].to_numpy()
calibration_label_bk = copy.deepcopy(calibration_label)
test_label = test_data[select_column[-1]].to_numpy()
test_label_bk = copy.deepcopy(test_label)

print(calibration_feature.shape, test_feature.shape, regularization_feature.shape)

# %%
import torch
import gc
from P_KNN_GPU import get_bootstrap_KNN_score_gpu, get_P_KNN_ACMG_score, evaluate_result
import copy

#Parameter setting
Pprior = 0.0441; # Prior probability of pathogenicity (changes w/ c)
w_calibration = None
n_calibration_in_window = 100   # minimum number of clinvar variants in a local window
frac_regularization_in_window = 0.03
batch_size = 512 # This is for A100, if V100, use 512
normalization= 'rank'
impute = True
mi_scaling = True
n_bootstrap = 100

p_value = 0.05
logbase = 1124

condition_string = 'P-KNN_REVEL+Component_meta'
valid_calibration_idx = ~np.isnan(calibration_feature).all(axis=1) 
calibration_array = calibration_feature[valid_calibration_idx]
calibration_label = copy.deepcopy(calibration_label_bk[valid_calibration_idx])

valid_test_idx = ~np.isnan(test_feature).all(axis=1) 
test_array = test_feature[valid_test_idx]
test_label = copy.deepcopy(test_label_bk[valid_test_idx])

valid_regularization_idx = ~np.isnan(regularization_feature).all(axis=1) 
regularization_array = regularization_feature[valid_regularization_idx]

print(f"calibration size: {calibration_array.shape[0]}, test size: {test_array.shape[0]}")

torch.cuda.empty_cache()
gc.collect()

test_results_array = get_bootstrap_KNN_score_gpu(calibration_array, test_array, regularization_array, 
                                                 calibration_label, Pprior, w_calibration, 
                                                 n_calibration_in_window, frac_regularization_in_window, 
                                                 normalization, impute, mi_scaling, n_bootstrap, batch_size)

np.save(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy', test_results_array)

test_results_array = np.load(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy')

P_KNN_pathogenic, P_KNN_benign, ACMG_scores = get_P_KNN_ACMG_score(test_results_array, p_value, Pprior, logbase)

test_data.loc[valid_test_idx, f"ACMGLLR"] = ACMG_scores 

evidence_strength_data, pathogenic_calibration_dict, benign_calibration_dict = evaluate_result(test_results_array,
                                                                                                  test_label, 
                                                                                                  p_value, 
                                                                                                  Pprior, 
                                                                                                  logbase, 
                                                                                                  category = condition_string, 
                                                                                                  show_plot=True, 
                                                                                                  save_name="REVEL+Component")

combine_data = pd.concat([combine_data, evidence_strength_data], ignore_index=True)
    
print("pathogenic evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Pathogenic variants']['Score'].mean():.3f}")
print("benign evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Benign variants']['Score'].mean():.3f}")

# %% [markdown]
# # REVEL BayesDel + Component

# %%
import copy
import numpy as np

select_column = ['REVEL_score', 
                 'BayesDel_nsfp33a_noAF', 
                 'SIFT_score',
                 'Polyphen2_HDIV_score', 
                 'Polyphen2_HVAR_score', 
                 'LRT_score',
                 'MutationTaster_score', 
                 'MutationAssessor_score', 
                 'FATHMM_score',
                 'VEST3_score', 
                 'GERP++_RS', 
                 'phyloP46way_primate',
                 'phyloP46way_placental', 
                 'phyloP100way_vertebrate',
                 'phastCons46way_primate', 'phastCons46way_placental',
                 'phastCons100way_vertebrate', 
                 'SiPhy_29way_logOdds', 
                 'PROVEAN_score',
                 'MutPred_score',
                 'ClinVar_annotation'
                ]

calibration_feature = calibration_data[select_column[:-1]].to_numpy()
test_feature = test_data[select_column[:-1]].to_numpy()
regularization_feature = gnomAD_set[select_column[:-1]].to_numpy()

calibration_label = calibration_data[select_column[-1]].to_numpy()
calibration_label_bk = copy.deepcopy(calibration_label)
test_label = test_data[select_column[-1]].to_numpy()
test_label_bk = copy.deepcopy(test_label)

print(calibration_feature.shape, test_feature.shape, regularization_feature.shape)

# %%
import torch
import gc
from P_KNN_GPU import get_bootstrap_KNN_score_gpu, get_P_KNN_ACMG_score, evaluate_result
import copy

#Parameter setting
Pprior = 0.0441; # Prior probability of pathogenicity (changes w/ c)
w_calibration = None
n_calibration_in_window = 100   # minimum number of clinvar variants in a local window
frac_regularization_in_window = 0.03
batch_size = 512 # This is for A100, if V100, use 512
normalization= 'rank'
impute = True
mi_scaling = True
n_bootstrap = 100

p_value = 0.05
logbase = 1124

condition_string = 'P-KNN_BayesDel+Component_meta'
valid_calibration_idx = ~np.isnan(calibration_feature).all(axis=1) 
calibration_array = calibration_feature[valid_calibration_idx]
calibration_label = copy.deepcopy(calibration_label_bk[valid_calibration_idx])

valid_test_idx = ~np.isnan(test_feature).all(axis=1) 
test_array = test_feature[valid_test_idx]
test_label = copy.deepcopy(test_label_bk[valid_test_idx])

valid_regularization_idx = ~np.isnan(regularization_feature).all(axis=1) 
regularization_array = regularization_feature[valid_regularization_idx]

print(f"calibration size: {calibration_array.shape[0]}, test size: {test_array.shape[0]}")

torch.cuda.empty_cache()
gc.collect()

test_results_array = get_bootstrap_KNN_score_gpu(calibration_array, test_array, regularization_array, 
                                                 calibration_label, Pprior, w_calibration, 
                                                 n_calibration_in_window, frac_regularization_in_window, 
                                                 normalization, impute, mi_scaling, n_bootstrap, batch_size)

np.save(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy', test_results_array)

test_results_array = np.load(f'/gpfs/home/pl2948/VariantInterpretation/KNNTestResultArrays/Clingen13_{condition_string}.npy')

P_KNN_pathogenic, P_KNN_benign, ACMG_scores = get_P_KNN_ACMG_score(test_results_array, p_value, Pprior, logbase)

test_data.loc[valid_test_idx, f"ACMGLLR"] = ACMG_scores 

evidence_strength_data, pathogenic_calibration_dict, benign_calibration_dict = evaluate_result(test_results_array,
                                                                                                  test_label, 
                                                                                                  p_value, 
                                                                                                  Pprior, 
                                                                                                  logbase, 
                                                                                                  category = condition_string, 
                                                                                                  show_plot=True, 
                                                                                                  save_name="REVEL+BayesDel+Component")

combine_data = pd.concat([combine_data, evidence_strength_data], ignore_index=True)
    
print("pathogenic evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Pathogenic variants']['Score'].mean():.3f}")
print("benign evidence mean", f"{evidence_strength_data[evidence_strength_data['Label']=='Benign variants']['Score'].mean():.3f}")

# %% [markdown]
# # Integrated final figure

# %% [markdown]
# ## 1D result

# %%
category_list = ['REVEL_score_meta', 'P-KNN_REVELComponent_meta',
       'P-KNN_REVEL+Component_meta', 'P-KNN_BayesDel+Component_meta', 'BayesDel_nsfp33a_noAF_meta']
combine_data = combine_data[combine_data['Category'].isin(category_list)]

# %%
import seaborn as sns

## violin plot
sns.set(style="ticks")
plt.figure(figsize=(12, 3.5))
ax = sns.violinplot(
    x="Category",
    y="Score", 
    hue="Label",   # Pathogenic and Benign 
    data=combine_data, 
    split=True,   # on each side of violin
    inner="box", 
    palette={"Benign variants": "blue", "Pathogenic variants": "red"},
    alpha=0.6, 
    density_norm='count',
    order=['REVEL_score_meta', 'P-KNN_REVELComponent_meta',
       'P-KNN_REVEL+Component_meta', 'P-KNN_BayesDel+Component_meta', 'BayesDel_nsfp33a_noAF_meta'],
    hue_order=['Pathogenic variants', 'Benign variants'] 
)

dark_gray = '0.3'

sns.boxplot(
    x="Category", y="Score", hue="Label", data=combine_data,
    showcaps=True,  
    showfliers=False,
    palette={"Pathogenic variants": "pink", "Benign variants": "#bae0f5"},
    width=0.1, dodge=True, ax=ax,
    whiskerprops={'color': dark_gray, 'linewidth': 1.5, 'zorder': 2},
    capprops={'color': dark_gray, 'linewidth': 1.5},
    medianprops={'color': dark_gray, 'linewidth': 1.5},
    boxprops={'zorder': 2, 'edgecolor': dark_gray, 'linewidth': 1.5},
    hue_order=['Pathogenic variants', 'Benign variants']

)

handles, labels = ax.get_legend_handles_labels()
n_hue = combine_data["Label"].nunique() 
ax.legend(handles[:n_hue], labels[:n_hue], loc="lower left", fontsize=12)

plt.xlabel("")
plt.xticks(fontsize=14)
plt.yticks([-8, -6, -4, -2, 0, 2, 4, 6, 8])
plt.ylabel("Evidence strength (LLR)", fontsize=14)
sns.despine(top=True, right=True)

plt.savefig("Fig4A.svg", format="svg")
plt.show()
